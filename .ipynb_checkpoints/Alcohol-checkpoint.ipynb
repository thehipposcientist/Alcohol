# %%
import pandas as pd
import seaborn as sn

# %%
drinks = pd.read_csv('drinks.csv')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ..                            ...
# 188                           7.7
# 189                           2.0
# 190                           0.1
# 191                           2.5
# 192                           4.7
#
# [193 rows x 5 columns]

# %%
life_data = pd.read_csv('life-expectancy.csv')

# %%
life_data_new = life_data[['Country Name','2019']].copy()

# %%
drinks['2019'] = 20
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol  2019
# 0                             0.0    20
# 1                             4.9    20
# 2                             0.7    20
# 3                            12.4    20
# 4                             5.9    20
# ..                            ...   ...
# 188                           7.7    20
# 189                           2.0    20
# 190                           0.1    20
# 191                           2.5    20
# 192                           4.7    20
#
# [193 rows x 6 columns]

# %%
life_data_new.columns = ['country' if x=='Country Name' else x for x in life_data_new.columns]
data = pd.concat(life_data_new['country'], drinks)
#merge concat join append READ DOCUMENTATION
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8516/294298768.py in <module>
#       1 life_data_new.columns = ['country' if x=='Country Name' else x for x in life_data_new.columns]
# ----> 2 data = pd.concat(life_data_new['country'], drinks)
#
# c:\python39\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# c:\python39\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     318     ):
#     319         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
# --> 320             raise TypeError(
#     321                 "first argument must be an iterable of pandas "
#     322                 f'objects, you passed an object of type "{type(objs).__name__}"'
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "Series"

# %%
data.dropna()
data
