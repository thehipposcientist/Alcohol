# %%
import pandas as pd
import seaborn as sn

# %%
drinks = pd.read_csv('drinks.csv')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
life_data = pd.read_csv('life-expectancy.csv')

# %%
life_data_new = life_data[['Country Name','2019']].copy()

# %%
drinks['2019'] = 20
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol  2019
# 0                             0.0    20
# 1                             4.9    20
# 2                             0.7    20
# ...

# %%
life_data_new.columns = ['country' if x=='Country Name' else x for x in life_data_new.columns]
data = drinks.append(life_data_new['country'])
data = data.drop_duplicates(keep=False)
life_data_new
# Out:
#                          country       2019
# 0                          Aruba  76.293000
# 1    Africa Eastern and Southern  64.005197
# 2                    Afghanistan  64.833000
# 3     Africa Western and Central  58.115723
# 4                         Angola  61.147000
# ..                           ...        ...
# 261                       Kosovo  72.495122
# 262                  Yemen, Rep.  66.125000
# 263                 South Africa  64.131000
# 264                       Zambia  63.886000
# 265                     Zimbabwe  61.490000
#
# [266 rows x 2 columns]

# %%
data.dropna()
data
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan            0.0              0.0            0.0
# 1            Albania           89.0            132.0           54.0
# 2            Algeria           25.0              0.0           14.0
# 3            Andorra          245.0            138.0          312.0
# 4             Angola          217.0             57.0           45.0
# ...              ...            ...              ...            ...
# 189          Vietnam          111.0              2.0            1.0
# 190            Yemen            6.0              0.0            0.0
# 191           Zambia           32.0             19.0            4.0
# 192         Zimbabwe           64.0             18.0            4.0
# country          NaN            NaN              NaN            NaN
#
#          total_litres_of_pure_alcohol  2019      0  \
# 0                                 0.0  20.0    NaN
# ...
